# %%
# !pip install pydantic-ai
# Out:
# Collecting pydantic-ai
#   Downloading pydantic_ai-0.4.2-py3-none-any.whl.metadata (11 kB)
# Collecting pydantic-ai-slim==0.4.2 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading pydantic_ai_slim-0.4.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting eval-type-backport>=0.2.0 (from pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting griffe>=1.3.2 (from pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading griffe-1.7.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: httpx>=0.27 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.28.1)
# Collecting opentelemetry-api>=1.28.0 (from pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading opentelemetry_api-1.35.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting pydantic-graph==0.4.2 (from pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading pydantic_graph-0.4.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: pydantic>=2.10 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2.11.5)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.4.1)
# Collecting anthropic>=0.52.0 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading anthropic-0.57.1-py3-none-any.whl.metadata (27 kB)
# Collecting boto3>=1.37.24 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading boto3-1.39.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting argcomplete>=3.5.0 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading argcomplete-3.6.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: prompt-toolkit>=3 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (3.0.50)
# Collecting rich>=13 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting cohere>=5.13.11 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading cohere-5.16.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting pydantic-evals==0.4.2 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading pydantic_evals-0.4.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting google-genai>=1.24.0 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading google_genai-1.25.0-py3-none-any.whl.metadata (41 kB)
# Collecting groq>=0.19.0 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading groq-0.30.0-py3-none-any.whl.metadata (16 kB)
# Collecting mcp>=1.9.4 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading mcp-1.11.0-py3-none-any.whl.metadata (44 kB)
# Collecting mistralai>=1.2.5 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading mistralai-1.9.2-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: openai>=1.76.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (1.84.0)
# Collecting google-auth>=2.36.0 (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: requests>=2.32.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2.32.3)
# Requirement already satisfied: anyio>=0 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-evals==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (4.9.0)
# Collecting logfire-api>=1.2.0 (from pydantic-evals==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading logfire_api-3.24.1-py3-none-any.whl.metadata (972 bytes)
# Requirement already satisfied: pyyaml>=6.0.2 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic-evals==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (6.0.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from anthropic>=0.52.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from anthropic>=0.52.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.10.0)
# Requirement already satisfied: sniffio in /home/codespace/.local/lib/python3.12/site-packages (from anthropic>=0.52.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/codespace/.local/lib/python3.12/site-packages (from anthropic>=0.52.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio>=0->pydantic-evals==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (3.10)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.27->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.27->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from pydantic>=2.10->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2.33.2)
# Collecting botocore<1.40.0,>=1.39.4 (from boto3>=1.37.24->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading botocore-1.39.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3>=1.37.24->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3>=1.37.24->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/codespace/.local/lib/python3.12/site-packages (from botocore<1.40.0,>=1.39.4->boto3>=1.37.24->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/codespace/.local/lib/python3.12/site-packages (from botocore<1.40.0,>=1.39.4->boto3>=1.37.24->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2.3.0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.40.0,>=1.39.4->boto3>=1.37.24->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (1.17.0)
# Collecting fastavro<2.0.0,>=1.9.4 (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading fastavro-1.11.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.7 kB)
# Collecting httpx-sse==0.4.0 (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: tokenizers<1,>=0.15 in /home/codespace/.python/current/lib/python3.12/site-packages (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.21.1)
# Collecting types-requests<3.0.0,>=2.0.0 (from cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading types_requests-2.32.4.20250611-py3-none-any.whl.metadata (2.1 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.32.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (3.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/codespace/.python/current/lib/python3.12/site-packages (from tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.33.0)
# Requirement already satisfied: filelock in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /home/codespace/.local/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (24.2)
# Requirement already satisfied: tqdm>=4.42.1 in /home/codespace/.python/current/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /home/codespace/.python/current/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15->cohere>=5.13.11->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (1.1.4)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth>=2.36.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting tenacity<9.0.0,>=8.2.3 (from google-genai>=1.24.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai>=1.24.0->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Requirement already satisfied: colorama>=0.4 in /home/codespace/.local/lib/python3.12/site-packages (from griffe>=1.3.2->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.4.6)
# Requirement already satisfied: jsonschema>=4.20.0 in /home/codespace/.local/lib/python3.12/site-packages (from mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (4.23.0)
# Collecting pydantic-settings>=2.5.2 (from mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting python-multipart>=0.0.9 (from mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting sse-starlette>=1.6.1 (from mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading sse_starlette-2.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting starlette>=0.27 (from mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading starlette-0.47.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting uvicorn>=0.23.1 (from mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/codespace/.local/lib/python3.12/site-packages (from jsonschema>=4.20.0->mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.23.1)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.28.0->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.28.0->pydantic-ai-slim==0.4.2->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: wcwidth in /home/codespace/.local/lib/python3.12/site-packages (from prompt-toolkit>=3->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (0.2.13)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings>=2.5.2->mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai) (2.19.1)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=7.0 (from uvicorn>=0.23.1->mcp>=1.9.4->pydantic-ai-slim[anthropic,bedrock,cli,cohere,evals,google,groq,mcp,mistral,openai,vertexai]==0.4.2->pydantic-ai)
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Downloading pydantic_ai-0.4.2-py3-none-any.whl (10 kB)
# Downloading pydantic_ai_slim-0.4.2-py3-none-any.whl (218 kB)
# Downloading pydantic_evals-0.4.2-py3-none-any.whl (52 kB)
# Downloading pydantic_graph-0.4.2-py3-none-any.whl (27 kB)
# Downloading anthropic-0.57.1-py3-none-any.whl (292 kB)
# Downloading argcomplete-3.6.2-py3-none-any.whl (43 kB)
# Downloading boto3-1.39.4-py3-none-any.whl (139 kB)
# Downloading botocore-1.39.4-py3-none-any.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 74.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
# Downloading cohere-5.16.1-py3-none-any.whl (291 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading fastavro-1.11.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 59.3 MB/s eta 0:00:00
# Downloading types_requests-2.32.4.20250611-py3-none-any.whl (20 kB)
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading google_genai-1.25.0-py3-none-any.whl (226 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading websockets-15.0.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
# Downloading griffe-1.7.3-py3-none-any.whl (129 kB)
# Downloading groq-0.30.0-py3-none-any.whl (131 kB)
# Downloading logfire_api-3.24.1-py3-none-any.whl (85 kB)
# Downloading mcp-1.11.0-py3-none-any.whl (155 kB)
# Downloading mistralai-1.9.2-py3-none-any.whl (411 kB)
# Downloading opentelemetry_api-1.35.0-py3-none-any.whl (65 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading sse_starlette-2.4.1-py3-none-any.whl (10 kB)
# Downloading starlette-0.47.1-py3-none-any.whl (72 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, websockets, types-requests, tenacity, python-multipart, python-dotenv, pyasn1, mdurl, logfire-api, jmespath, httpx-sse, griffe, fastavro, eval-type-backport, click, cachetools, argcomplete, uvicorn, starlette, sse-starlette, rsa, pyasn1-modules, markdown-it-py, importlib-metadata, botocore, s3transfer, rich, pydantic-settings, pydantic-graph, opentelemetry-api, mistralai, groq, google-auth, anthropic, pydantic-ai-slim, mcp, google-genai, cohere, boto3, pydantic-evals, pydantic-ai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41/41 [pydantic-ai]m 38/41 [boto3]]genai]lim]
# Successfully installed anthropic-0.57.1 argcomplete-3.6.2 boto3-1.39.4 botocore-1.39.4 cachetools-5.5.2 click-8.2.1 cohere-5.16.1 eval-type-backport-0.2.2 fastavro-1.11.1 google-auth-2.40.3 google-genai-1.25.0 griffe-1.7.3 groq-0.30.0 httpx-sse-0.4.0 importlib-metadata-8.7.0 jmespath-1.0.1 logfire-api-3.24.1 markdown-it-py-3.0.0 mcp-1.11.0 mdurl-0.1.2 mistralai-1.9.2 opentelemetry-api-1.35.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-ai-0.4.2 pydantic-ai-slim-0.4.2 pydantic-evals-0.4.2 pydantic-graph-0.4.2 pydantic-settings-2.10.1 python-dotenv-1.1.1 python-multipart-0.0.20 rich-14.0.0 rsa-4.9.1 s3transfer-0.13.0 sse-starlette-2.4.1 starlette-0.47.1 tenacity-8.5.0 types-requests-2.32.4.20250611 uvicorn-0.35.0 websockets-15.0.1 zipp-3.23.0

# %%
import requests
from minsearch import AppendableIndex

docs_url = 'https://github.com/alexeygrigorev/llm-rag-workshop/raw/main/notebooks/documents.json'
docs_response = requests.get(docs_url)
documents_raw = docs_response.json()

documents = []

for course in documents_raw:
    course_name = course['course']

    for doc in course['documents']:
        doc['course'] = course_name
        documents.append(doc)

index = AppendableIndex(
    text_fields=["question", "text", "section"],
    keyword_fields=["course"]
)

index.fit(documents)

def search(query):
    boost = {'question': 3.0, 'section': 0.5}

    results = index.search(
        query=query,
        filter_dict={'course': 'data-engineering-zoomcamp'},
        boost_dict=boost,
        num_results=5,
        output_ids=True
    )

    return results

# %%
from pydantic_ai import Agent, RunContext

# %%
developer_prompt = """
You're a course teaching assistant. 
You're given a question from a course student and your task is to answer it.

Use FAQ if your own knowledge is not sufficient to answer the question.

At the end of each response, ask the user a follow up question based on your answer.
""".strip()

# %%
chat_agent = Agent(  
    'openai:gpt-4o-mini',
    system_prompt=developer_prompt
)

# %%
def add_entry(question, answer):
    doc = {
        'question': question,
        'text': answer,
        'section': 'user added',
        'course': 'data-engineering-zoomcamp'
    }
    index.append(doc)

# %%
from typing import Dict


@chat_agent.tool
def search_tool(ctx: RunContext, query: str) -> Dict[str, str]:
    """
    Search the FAQ for relevant entries matching the query.

    Parameters
    ----------
    query : str
        The search query string provided by the user.

    Returns
    -------
    list
        A list of search results (up to 5), each containing relevance information 
        and associated output IDs.
    """
    print(f"search('{query}')")
    return search(query)


@chat_agent.tool
def add_entry_tool(ctx: RunContext, question: str, answer: str) -> None:
    """
    Add a new question-answer entry to FAQ.

    This function creates a document with the given question and answer, 
    tagging it as user-added content.

    Parameters
    ----------
    question : str
        The question text to be added to the index.

    answer : str
        The answer or explanation corresponding to the question.

    Returns
    -------
    None
    """
    return add_entry(question, answer)

# %%
user_prompt = "I just discovered the course. Can I join now?"
agent_run = await chat_agent.run(user_prompt)
print(agent_run.output)
# Out:
# search('Can I join the course now')
# Yes, you can still join the course even if it has already started. You don't need to register formally; you can go ahead and start learning and submitting homework without being on any registered list. Just be mindful of deadlines for final projects.
#
# However, note that if you want to receive a certificate, you would need to complete the course with a "live" cohort, as certificates are not awarded for completing the course in self-paced mode.
#
# Do you have any specific questions about the course content or how to access it?
